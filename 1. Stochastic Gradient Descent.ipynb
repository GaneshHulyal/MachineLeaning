# %%
import numpy as np
import pandas as pd
import random
import pylab
from scipy import stats
from mpl_toolkits.mplot3d import Axes3D
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# Make a prediction with coefficients
import pylab
def predict(row, coefficients):
    yhat = coefficients[0]
    for i in range(len(row)-1):
        yhat += coefficients[i + 1] * row[i] 
    return yhat

# %%
# Estimate linear regression coefficients using stochastic gradient descent
def coefficients_sgd(train, l_rate, n_epoch):
    coef = [0.0 for i in range(len(train[0]))]
    print(coef)
    for epoch in range(n_epoch):
        sum_error = 0.0
        for row in train:
            yhat = predict(row, coef)
            error = yhat - row[-1]
            sum_error += error **2          
            coef[0] = coef[0] - l_rate * error
            for i in range(len(row)-1):
                coef[i + 1] = coef[i + 1] - l_rate * error * row[i]
        print('>epoch=%d, lrate=%.3f, error=%.3f' % (epoch, l_rate, sum_error))
        
    return coef

# %%
import csv

p=[]
dataset=[]
with open('0.txt') as csvfile:
        reader = csv.reader(csvfile)
        for row in reader:
            x = float(row[0])
            y = float(row[1])
            p =[x,y]
            dataset.append(p)
            
l_rate = 0.01
n_epoch = 1000

coef = coefficients_sgd(dataset, l_rate, n_epoch)
# Out:
# [0.0, 0.0]
# >epoch=0, lrate=0.010, error=11309.693
# >epoch=1, lrate=0.010, error=2287.231
# >epoch=2, lrate=0.010, error=1233.980
# >epoch=3, lrate=0.010, error=1102.157
# >epoch=4, lrate=0.010, error=1085.182
# >epoch=5, lrate=0.010, error=1082.832
# >epoch=6, lrate=0.010, error=1082.452
# >epoch=7, lrate=0.010, error=1082.373
# >epoch=8, lrate=0.010, error=1082.352
# >epoch=9, lrate=0.010, error=1082.345
# >epoch=10, lrate=0.010, error=1082.343
# >epoch=11, lrate=0.010, error=1082.342
# >epoch=12, lrate=0.010, error=1082.342
# >epoch=13, lrate=0.010, error=1082.342
# >epoch=14, lrate=0.010, error=1082.342
# >epoch=15, lrate=0.010, error=1082.342
# >epoch=16, lrate=0.010, error=1082.342
# >epoch=17, lrate=0.010, error=1082.342
# >epoch=18, lrate=0.010, error=1082.342
# >epoch=19, lrate=0.010, error=1082.342
# >epoch=20, lrate=0.010, error=1082.342
# >epoch=21, lrate=0.010, error=1082.342
# >epoch=22, lrate=0.010, error=1082.342
# >epoch=23, lrate=0.010, error=1082.342
# ...

# %%
samples=len(dataset)
m=[]
n=[]
y_predict=[]
for i in range(samples):
    m.append(dataset[i][0])
    n.append(dataset[i][1])
    q=coef[0] + coef[1]*m[i]
    y_predict.append(q)
    

pylab.plot(m,n,'o')
pylab.plot(m,y_predict,'k-')
pylab.show()
print(coef)
# Out:
# [14.772103719648129, 0.29668887200145033]

# %%
import numpy as np

# %%
epoch_array=[]
Error_array=[]
def coefficients_sgd1(train, l_rate, n_epoch):
    coef = [0.0 for i in range(len(train[0]))]
    #print(coef)
    for epoch in range(n_epoch):
        sum_error = 0.0
        for row in train:
            yhat = predict(row, coef)
            error = yhat - row[-1]
            sum_error += error **2          
            coef[0] = coef[0] - l_rate * error
            for i in range(len(row)-1):
                coef[i + 1] = coef[i + 1] - l_rate * error * row[i]
        print('>epoch=%d, lrate=%.3f, error=%.3f' % (epoch, l_rate, sum_error))
        epoch_array.append(epoch)
        Error_array.append(sum_error)
        
    return coef

# %%
l_rate = 0.001
n_epoch = 1000
coef = coefficients_sgd1(dataset, l_rate, n_epoch)
# Out:
# >epoch=0, lrate=0.001, error=25952.097
# >epoch=1, lrate=0.001, error=16878.624
# >epoch=2, lrate=0.001, error=13892.264
# >epoch=3, lrate=0.001, error=11466.650
# >epoch=4, lrate=0.001, error=9496.515
# >epoch=5, lrate=0.001, error=7896.326
# >epoch=6, lrate=0.001, error=6596.614
# >epoch=7, lrate=0.001, error=5540.956
# >epoch=8, lrate=0.001, error=4683.522
# >epoch=9, lrate=0.001, error=3987.090
# >epoch=10, lrate=0.001, error=3421.428
# >epoch=11, lrate=0.001, error=2961.979
# >epoch=12, lrate=0.001, error=2588.799
# >epoch=13, lrate=0.001, error=2285.689
# >epoch=14, lrate=0.001, error=2039.491
# >epoch=15, lrate=0.001, error=1839.519
# >epoch=16, lrate=0.001, error=1677.093
# >epoch=17, lrate=0.001, error=1545.163
# >epoch=18, lrate=0.001, error=1438.002
# >epoch=19, lrate=0.001, error=1350.960
# >epoch=20, lrate=0.001, error=1280.259
# >epoch=21, lrate=0.001, error=1222.831
# >epoch=22, lrate=0.001, error=1176.184
# >epoch=23, lrate=0.001, error=1138.294
# ...

# %%
plt.plot(epoch_array,Error_array)
plt.xlabel("Epoch Number")
plt.ylabel("Error Rate")
plt.show()

# %%
alpha_list=np.array([0.0001,0.01,0.001,0.002,0.002,0.003,0.0004,0.008,0.009,0.001])
error_list=np.zeros(10)

# %%
def coefficients_sgd_Qno2(train, l_rate, n_epoch):
    coef = [0.0 for i in range(len(train[0]))]
    #print(coef)
    for epoch in range(n_epoch):
        #print("epoch",epoch)
        sum_error = 0.0
        for row in train:
            #print(row)
            yhat = predict(row, coef)
            error = yhat - row[-1]
            sum_error += error **2 
            
            coef[0] = coef[0] - l_rate * error
            for i in range(len(row)-1):
                coef[i + 1] = coef[i + 1] - l_rate * error * row[i]
         #print(sum_error)
        #print('>epoch=%d, lrate=%.3f, error=%.3f' % (epoch, l_rate, sum_error))
        
    return sum_error

# %%
for i in range(10):
    error_list[i]=coefficients_sgd_Qno2(dataset,alpha_list[i],100)

# %%
plt.plot(alpha_list,error_list)
plt.xlabel("Learning Rate")
plt.ylabel("Error Rate")
# Out:
# Text(0, 0.5, 'Error Rate')

# %%
def coefficients_sgd_Qno2(train, l_rate, n_epoch):
    coef = [0.0 for i in range(len(train[0]))]
    #print(coef)
    for epoch in range(n_epoch):
        #print("epoch",epoch)
        sum_error = 0.0
        for row in train:
            #print(row)
            yhat = predict(row, coef)
            error = yhat - row[-1]
            sum_error += error **2 
            
            coef[0] = coef[0] - l_rate * error
            for i in range(len(row)-1):
                coef[i + 1] = coef[i + 1] - l_rate * error * row[i]
         #print(sum_error)
        #print('>epoch=%d, lrate=%.3f, error=%.3f' % (epoch, l_rate, sum_error))
        
    return coef[0],coef[1],sum_error

# %%
theta0_list=np.zeros(10)
theta1_list=np.zeros(10)
sum_error_list=np.zeros(10)
for i in range(10):
    theta0_list[i],theta1_list[i],error_list[i]=coefficients_sgd_Qno2(dataset,alpha_list[i],100)
    print("Theta 0:",theta0_list[i],"|","Theta 1:",theta1_list[i],"Sum Error: ","|",error_list[i])
# Out:
# Theta 0: 9.820367771595246 | Theta 1: 1.3529091846167383 Sum Error:  | 3674.978514168228
# Theta 0: 14.772103719648129 | Theta 1: 0.29668887200145033 Sum Error:  | 1082.3418733268782
# Theta 0: 14.777920980022037 | Theta 1: 0.2527326046778686 Sum Error:  | 974.2611155157151
# Theta 0: 14.777349595592707 | Theta 1: 0.27436232907361463 Sum Error:  | 986.8010463778264
# Theta 0: 14.777349595592707 | Theta 1: 0.27436232907361463 Sum Error:  | 986.8010463778264
# Theta 0: 14.776747861913531 | Theta 1: 0.2866377803739138 Sum Error:  | 998.7179895817033
# Theta 0: 14.558287426699113 | Theta 1: 0.28275305697804914 Sum Error:  | 971.5023482197843
# Theta 0: 14.774678805398864 | Theta 1: 0.2976399493831288 Sum Error:  | 1057.489888684946
# Theta 0: 14.773527777277277 | Theta 1: 0.2971363149265972 Sum Error:  | 1069.753784164802
# Theta 0: 14.777920980022037 | Theta 1: 0.2527326046778686 Sum Error:  | 974.2611155157151

# %%
plt.plot(theta0_list,error_list)
plt.xlabel("Theta 0")
plt.ylabel("Error")
plt.show()

plt.plot(theta1_list,error_list)
plt.xlabel("Theta 1")
plt.ylabel("Error")
plt.show()

# %%
with open('0.txt') as csvfile:
        reader = csv.reader(csvfile)
        x=[]
        y=[]
        for row in reader: 
            x.append(row[0])
            y.append(row[1])

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.33)
        

j=[]
train_dataset=[]            
for i in range(len(X_train)):
    j=[X_train[i],y_train[i]]
    train_dataset.append(j)
    
q=[]
test_dataset=[]
for i in range(len(X_test)):
    q=[X_test[i],y_test[i]]
    test_dataset.append(q)

# %%
# Make a prediction with coefficients

import pylab
def predict1(row, coefficients):
    yhat = coefficients[0]
    for i in range(len(row)-1):
        yhat += coefficients[i + 1] * row[i]
    return yhat

# %%
def coefficients_sgd5(train, l_rate, n_epoch):
    coef = [0.0 for i in range(len(train[0]))]
    #print(coef)
    for epoch in range(n_epoch):
        #print("epoch",epoch)
        sum_error = 0.0
        for row in train:
            #print(row)
            yhat = predict1(row, coef)
            error = yhat -row[-1]
            sum_error += error **2 
            
            coef[0] = coef[0] - float(l_rate) * float(error)
            for i in range(len(row)-1):
                coef[i + 1] = coef[i + 1] - l_rate * error * row[i]
         #print(sum_error)
        #print('>epoch=%d, lrate=%.3f, error=%.3f' % (epoch, l_rate, sum_error))
        
        
    return coef[0],coef[1],sum_error

# %%
learning_rate=0.01
epoch=1000
theta0,theta1,error=coefficients_sgd5(train_dataset,learning_rate,epoch)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-165-f211ab58a8d4> in <module>
#       1 learning_rate=0.01
#       2 epoch=1000
# ----> 3 theta0,theta1,error=coefficients_sgd5(train_dataset,learning_rate,epoch)
#
# <ipython-input-164-135ba0518d4c> in coefficients_sgd5(train, l_rate, n_epoch)
#       7         for row in train:
#       8             #print(row)
# ----> 9             yhat = predict1(row, coef)
#      10             error = yhat -row[-1]
#      11             sum_error += error **2
#
# <ipython-input-163-c2162724749f> in predict1(row, coefficients)
#       5     yhat = coefficients[0]
#       6     for i in range(len(row)-1):
# ----> 7         yhat += coefficients[i + 1] * row[i]
#       8     return yhat
#
# TypeError: can't multiply sequence by non-int of type 'float'
