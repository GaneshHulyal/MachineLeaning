# %%
import numpy as np
import pandas as pd
import random
import pylab
from scipy import stats
from mpl_toolkits.mplot3d import Axes3D
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
learning_rate_list=[0.1,0.001,0.0001,0.00001,0.000001,0.0000001,0.8,0.008,0.002,0.0003]
theta0_list=np.zeros(10)
theta1_list=np.zeros(10)
Error_rate=np.zeros(10)

# %%
def compute_cost_function(m, t0, t1, x, y):
  return 1/2/m * sum([(t0 + t1* np.asarray([x[i]]) - y[i])**2 for i in range(m)])

# %%
error_list=[]
epoch_list=[]
def gradient_descent(alpha, x, y, ep=0.0001, max_iter=1000):
    converged = False
    iter = 0
    m = x.shape[0] # number of samples

    # initial theta
    t0 = 0
    t1 = 0

    # total error, J(theta)
    J = compute_cost_function(m, t0, t1, x, y)
    print('J=', J);
    # Iterate Loop
    num_iter = 0
    while not converged:
        # for each training sample, compute the gradient (d/d_theta j(theta))
        grad0 = 1.0/m * sum([(t0 + t1*np.asarray([x[i]]) - y[i]) for i in range(m)]) 
        grad1 = 1.0/m * sum([(t0 + t1*np.asarray([x[i]]) - y[i])*np.asarray([x[i]]) for i in range(m)])

        # update the theta_temp
        temp0 = t0 - alpha * grad0
        temp1 = t1 - alpha * grad1
    
        # update theta
        t0 = temp0
        t1 = temp1

        # mean squared error
        e = compute_cost_function(m, t0, t1, x, y)
        print ('J = ', e)
        J = e   # update error 
        error_list.append(J)
        epoch_list.append(iter)
        iter += 1  # update iter
        
        if iter == max_iter:
            print ('Max interactions exceeded!')
            converged = True

    return t0,t1,J

# %% [markdown]
# Question 1:

# %%
#Question Number: 1 Epoch vs. Error

plt.xlabel("Epoch No.")
plt.ylabel("error")
plt.plot(epoch_list,error_list)
plt.show()

# %%
for i in range(0,10):
    theta0_list[i], theta1_list[i],Error_rate[i] = gradient_descent(learning_rate_list[i], x, y, ep, max_iter=1000)
# Out:
# J= [121.93655238]
# J =  [69.7883682]
# J =  [43.37496971]
# J =  [29.86570332]
# J =  [22.83146109]
# J =  [19.05062786]
# J =  [16.90870721]
# J =  [15.59645706]
# J =  [14.70811666]
# J =  [14.0400988]
# J =  [13.49012456]
# J =  [13.00668466]
# J =  [12.56371687]
# J =  [12.14791785]
# J =  [11.75238549]
# J =  [11.37343311]
# J =  [11.00899296]
# J =  [10.65781601]
# J =  [10.31907079]
# J =  [9.99214206]
# J =  [9.67652979]
# J =  [9.37179822]
# J =  [9.07755016]
# J =  [8.79341389]
# J =  [8.51903638]
# J =  [8.25407969]
# J =  [7.99821895]
# J =  [7.75114121]
# J =  [7.51254461]
# J =  [7.28213787]
# J =  [7.05963978]
# J =  [6.84477882]
# J =  [6.63729285]
# J =  [6.4369287]
# J =  [6.24344191]
# J =  [6.05659643]
# J =  [5.8761643]
# J =  [5.70192537]
# J =  [5.53366707]
# J =  [5.37118412]
# J =  [5.21427829]
# J =  [5.06275815]
# J =  [4.91643882]
# J =  [4.77514181]
# J =  [4.63869472]
# J =  [4.50693108]
# J =  [4.37969014]
# J =  [4.25681665]
# J =  [4.13816072]
# ...

# %% [markdown]
# Question No. 2 Learning Rate Vs. Error

# %%
plt.plot(learning_rate_list,Error_rate)
plt.xlabel("Learning Rate")
plt.ylabel("Error Rate")
# Out:
# Text(0, 0.5, 'Error Rate')

# %% [markdown]
# Question No. 3

# %%
#Theta 0 Vs. Error Cost
plt.plot(theta0_list,Error_rate)
plt.xlabel("Theta 0")
plt.ylabel("Error List")
plt.show()

#Theta 1 Vs. Error Cost
plt.plot(theta1_list,Error_rate)
plt.xlabel("Theta 1")
plt.ylabel("Error List")
plt.show()

# %%
Question No.5

# %%
def plot_cost_function(x, y, m):
    t0 = list(range(0, x.shape[0]))
    j_values = []
    for i in range(len(t0)):
        j_values.append(compute_cost_function(m, i, i, x, y)[0])
    print ('j_values', len(j_values), len(x), len(y))
    fig = plt.figure()
    ax = fig.gca(projection='3d')
    ax.plot(x, y, j_values, label='parametric curve')
    ax.legend()
    plt.show()

# %%
if __name__ == '__main__':
  
    df = pd.read_csv('0.txt', names=['x','y'])
    x = df['x']
    y = df['y']
     
    alpha = 0.01 # learning rate
    ep = 0.0001 # convergence criteria

    # call gredient decent, and get intercept(=theta0) and slope(=theta1)
    theta0, theta1 = gradient_descent(alpha, x, y, ep, max_iter=1000)
    print ('theta0 = ' + str(theta0)+' theta1 = '+str(theta1))
    #plot_cost_function(x, y, x.shape[0])

    # plot
    for i in range(x.shape[0]):
        y_predict = theta0 + theta1*x 

    pylab.plot(x,y,'o')
    pylab.plot(x,y_predict,'k-')
    pylab.show()
    print ("Done!")
# Out:
# J= [121.93655238]
# J =  [89.60756864]
# J =  [67.35914941]
# J =  [52.04217164]
# J =  [41.49130454]
# J =  [34.2176709]
# J =  [29.19752158]
# J =  [25.72692852]
# J =  [23.32187203]
# J =  [21.64954093]
# J =  [20.48109473]
# J =  [19.65918292]
# J =  [19.07561143]
# J =  [18.65598599]
# J =  [18.34915304]
# J =  [18.11993929]
# J =  [17.94415942]
# J =  [17.80518345]
# J =  [17.69157641]
# J =  [17.59547543]
# J =  [17.51147379]
# J =  [17.43585365]
# J =  [17.36605839]
# J =  [17.30032988]
# J =  [17.23745903]
# J =  [17.17661423]
# J =  [17.11722349]
# J =  [17.05889328]
# J =  [17.00135281]
# J =  [16.94441566]
# J =  [16.88795346]
# J =  [16.83187772]
# J =  [16.77612739]
# J =  [16.7206603]
# J =  [16.66544722]
# J =  [16.61046787]
# J =  [16.5557081]
# J =  [16.50115796]
# J =  [16.44681042]
# J =  [16.39266044]
# J =  [16.33870436]
# J =  [16.28493944]
# J =  [16.23136363]
# J =  [16.17797529]
# J =  [16.12477311]
# J =  [16.07175599]
# J =  [16.01892297]
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.33)
X_train=np.array(X_train)
X_test=np.array(X_test)
y_train=np.array(y_train)
y_test=np.array(y_test)

# %%
r0,r1 = gradient_descent_train_test(0.0001, X_train, y_train, 0.0001, max_iter=1000)
# Out:
# Max interactions exceeded!

# %%
def gradient_descent_train_test(alpha, x, y, ep=0.0001, max_iter=1000):
    converged = False
    iter = 0
    m = x.shape[0] # number of samples

    # initial theta
    t0 = 0
    t1 = 0

    # total error, J(theta)
    J = compute_cost_function(m, t0, t1, x, y)
    #print('J=', J);
    # Iterate Loop
    num_iter = 0
    while not converged:
        # for each training sample, compute the gradient (d/d_theta j(theta))
        grad0 = 1.0/m * sum([(t0 + t1*np.asarray([x[i]]) - y[i]) for i in range(m)]) 
        grad1 = 1.0/m * sum([(t0 + t1*np.asarray([x[i]]) - y[i])*np.asarray([x[i]]) for i in range(m)])

        # update the theta_temp
        temp0 = t0 - alpha * grad0
        temp1 = t1 - alpha * grad1
    
        # update theta
        t0 = temp0
        t1 = temp1

        # mean squared error
        e = compute_cost_function(m, t0, t1, x, y)
        #print ('J = ', e)
        J = e   # update error 
        iter += 1  # update iter
    
        if iter == max_iter:
            print ('Max interactions exceeded!')
            converged = True

    return t0,t1

# %%
train_error=compute_cost_function(X_train.shape[0],r0,r1,X_train,y_train)
print("train_error :",train_error)
# Out:
# tarin_error : [22.283546]

# %%
train_error=compute_cost_function(X_test.shape[0],r0,r1,X_test,y_test)
print("test_error :",train_error)
# Out:
# test_error : [20.43790335]

# %%
def earlyStop(alpha,x,y,ep=0.0001, max_iter=1000):
